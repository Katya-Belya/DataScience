# %%
#import necessary libraries

#for importing data and wrangling
import pandas as pd
import numpy as np

# %%
#for plotting images & adjusting colors
import matplotlib.pyplot as plt
import matplotlib as mpl
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image

# %%
# read in the data
df = pd.read_csv('Documents/customer_comment2.csv')

# %%
df.head()
# Out:
#                                              comment
# 0                           We need inepter for deaf
# 1  People contacting me I do not get any response...
# 2  Aye whole new director ,Fire the mayor.... Get...
# 3  None, just follow through with what experience...
# 4  The entire program needs to be reconstructed a...

# %%
# Start with one column
text = (' '.join(df['comment'].astype(str).values))

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["N/A", "NA", "None", "Nothing", "Unknown", "Need", "Help", "Job", "nan"])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
